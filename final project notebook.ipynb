# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv(r'final_data (2).csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116581 entries, 0 to 116580
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       116581 non-null  object
#  1   order_item_id                  116581 non-null  int64
#  2   product_id                     116581 non-null  object
#  3   seller_id                      116581 non-null  object
#  4   shipping_limit_date            116581 non-null  object
#  5   price                          116581 non-null  float64
#  6   freight_value                  116581 non-null  float64
#  7   payment_sequential             116581 non-null  int64
#  8   payment_type                   116581 non-null  object
#  9   payment_installments           116581 non-null  int64
#  10  payment_value                  116581 non-null  float64
#  11  review_id                      116581 non-null  object
# ...

# %%
df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value  payment_sequential  \
# 0  2017-09-19 09:45:35   58.90          13.29                   1
# 1  2017-05-03 11:05:13  239.90          19.93                   1
# ...

# %%
sns.heatmap(df.isnull()) # for correlation
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value', 'payment_sequential',
#        'payment_type', 'payment_installments', 'payment_value', 'review_id',
#        'review_score', 'review_comment_title', 'review_comment_message',
#        'review_creation_date', 'review_answer_timestamp', 'customer_id',
#        'order_status', 'order_purchase_timestamp', 'order_approved_at',
#        'order_delivered_carrier_date', 'order_delivered_customer_date',
#        'order_estimated_delivery_date', 'customer_unique_id',
#        'customer_zip_code_prefix', 'customer_city', 'customer_state',
#        'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'seller_zip_code_prefix', 'seller_city', 'seller_state',
#        'product_category_name_english'],
#       dtype='object')

# %%
df['customer_unique_id'],['customer_zip_code_prefix'],['customer_city']
# Out:
# (0         871766c5855e863f6eccc05f988b23cb
#  1         eb28e67c4c0b83846050ddfb8a35d051
#  2         3818d81c6709e39d06b2738a8d3a2474
#  3         af861d436cfc08b2c2ddefd0ba074622
#  4         64b576fb70d441e8f1b2d7d446e483c5
#                          ...
#  116576    0c9aeda10a71f369396d0c04dce13a64
#  116577    0da9fe112eae0c74d3ba1fe16de0988b
#  116578    cd79b407828f02fdbba457111c38e4c4
#  116579    eb803377c9315b564bdedad672039306
#  116580    cd76a00d8e3ca5e6ab9ed9ecb6667ac4
#  Name: customer_unique_id, Length: 116581, dtype: object,
#  ['customer_zip_code_prefix'],
#  ['customer_city'])

# %%
df.describe()
# Out:
#        order_item_id          price  freight_value  payment_sequential  \
# count  116581.000000  116581.000000  116581.000000       116581.000000
# mean        1.196953     120.751369      20.062550            1.093369
# std         0.701350     183.848421      15.845515            0.727240
# min         1.000000       0.850000       0.000000            1.000000
# 25%         1.000000      39.900000      13.080000            1.000000
# 50%         1.000000      74.900000      16.320000            1.000000
# 75%         1.000000     134.900000      21.220000            1.000000
# max        21.000000    6735.000000     409.680000           29.000000
#
#        payment_installments  payment_value   review_score  \
# count         116581.000000  116581.000000  116581.000000
# mean               2.949614     172.910258       4.017507
# std                2.783798     267.622516       1.397886
# min                0.000000       0.000000       1.000000
# ...

# %%
top_customers = df.groupby('customer_id')['payment_value'].sum().nlargest(10)

plt.figure(figsize=(10, 5))
sns.barplot(x=top_customers.index, y=top_customers.values, palette="Blues_r")
plt.xticks(rotation=90)
plt.xlabel("Customer ID")
plt.ylabel("Total Spending")
plt.title("Top 10 Spending Customers")
plt.show()
# Out:
# C:\Users\yassein ahmed\AppData\Local\Temp\ipykernel_14100\1365010211.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_customers.index, y=top_customers.values, palette="Blues_r")

# %%
state_orders = df['customer_state'].value_counts()

plt.figure(figsize=(12, 5))
sns.barplot(x=state_orders.index, y=state_orders.values, palette="coolwarm")
plt.xlabel("State")
plt.ylabel("Number of Orders")
plt.title("Orders by State")
plt.xticks(rotation=0)
plt.show()
# Out:
# C:\Users\yassein ahmed\AppData\Local\Temp\ipykernel_14100\172930155.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=state_orders.index, y=state_orders.values, palette="coolwarm")

# %%
top_products = df['product_id'].value_counts().nlargest(10)

plt.figure(figsize=(10, 5))
sns.barplot(x=top_products.index, y=top_products.values, palette="viridis")
plt.xticks(rotation=90)
plt.xlabel("Product ID")
plt.ylabel("Number of Orders")
plt.title("Top 10 Best-Selling Products")
plt.show()
# Out:
# C:\Users\yassein ahmed\AppData\Local\Temp\ipykernel_14100\1725487372.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_products.index, y=top_products.values, palette="viridis")

# %%
top_products = df['product_category_name'].value_counts().nlargest(10)

plt.figure(figsize=(10, 5))
sns.barplot(x=top_products.index, y=top_products.values, palette="viridis")
plt.xticks(rotation=90)
plt.xlabel("Product ID")
plt.ylabel("Number of Orders")
plt.title("Top 10 Best-Selling Products")
plt.show()
# Out:
# C:\Users\yassein ahmed\AppData\Local\Temp\ipykernel_14100\246424996.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_products.index, y=top_products.values, palette="viridis")

# %%
category_reviews = df.groupby('product_category_name')['review_score'].mean().sort_values(ascending=False).head(10)

plt.figure(figsize=(12, 5))
sns.barplot(x=category_reviews.index, y=category_reviews.values, palette="rocket")
plt.xticks(rotation=90)
plt.xlabel("Product Category")
plt.ylabel("Average Review Score")
plt.title("Top 10 Product Categories by Review Score")
plt.show()
# Out:
# C:\Users\yassein ahmed\AppData\Local\Temp\ipykernel_14100\2464185524.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_reviews.index, y=category_reviews.values, palette="rocket")

# %%
top_sellers = df['seller_id'].value_counts().nlargest(10)

plt.figure(figsize=(10, 5))
sns.barplot(x=top_sellers.index, y=top_sellers.values, palette="magma")
plt.xticks(rotation=90)
plt.xlabel("Seller ID")
plt.ylabel("Number of Orders")
plt.title("Top 10 Sellers by Sales")
plt.show()
# Out:
# C:\Users\yassein ahmed\AppData\Local\Temp\ipykernel_14100\4099688707.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_sellers.index, y=top_sellers.values, palette="magma")

# %%
df['delivery_time'] = (pd.to_datetime(df['order_delivered_customer_date']) - pd.to_datetime(df['order_purchase_timestamp'])).dt.days
shipping_efficiency = df.groupby('seller_id')['delivery_time'].mean().sort_values().head(10)

plt.figure(figsize=(12, 5))
sns.barplot(x=shipping_efficiency.index, y=shipping_efficiency.values, palette="coolwarm")
plt.xticks(rotation=90)
plt.xlabel("Seller ID")
plt.ylabel("Average Delivery Time (Days)")
plt.title("Top 10 Sellers with Fastest Delivery")
plt.show()
# Out:
# C:\Users\yassein ahmed\AppData\Local\Temp\ipykernel_14100\2977223643.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=shipping_efficiency.index, y=shipping_efficiency.values, palette="coolwarm")

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['delivery_time'].dropna(), bins=30, kde=True, color="purple")
plt.xlabel("Delivery Time (Days)")
plt.ylabel("Frequency")
plt.title("Distribution of Delivery Times")
plt.show()

# %%
df['late_delivery'] = df['order_delivered_customer_date'] > df['order_estimated_delivery_date']
late_deliveries = df['late_delivery'].value_counts()

plt.figure(figsize=(6, 5))
sns.barplot(x=late_deliveries.index, y=late_deliveries.values, palette="Reds")
plt.xticks(ticks=[0, 1], labels=["On Time", "Late"])
plt.xlabel("Delivery Status")
plt.ylabel("Number of Orders")
plt.title("Late vs On-Time Deliveries")
plt.show()
# Out:
# C:\Users\yassein ahmed\AppData\Local\Temp\ipykernel_14100\4094846939.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=late_deliveries.index, y=late_deliveries.values, palette="Reds")

# %%
df['hour'] = pd.to_datetime(df['order_purchase_timestamp']).dt.hour 

# Group by hour
hourly_sales = df.groupby('hour').size().reset_index(name='count')

# Plot
plt.figure(figsize=(10, 5))
plt.bar(hourly_sales['hour'], hourly_sales['count'], color='black')
plt.xlabel("Hour of the Day")
plt.ylabel("Number of Orders")
plt.title("Orders per Hour")
plt.xticks(range(24))  # Show all hours from 0 to 23
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
payment_types = df['payment_type'].value_counts()

plt.figure(figsize=(8, 5))
sns.barplot(x=payment_types.index, y=payment_types.values, palette="Set2")
plt.xlabel("Payment Method")
plt.ylabel("Number of Transactions")
plt.title("Popular Payment Methods")
plt.show()
# Out:
# C:\Users\yassein ahmed\AppData\Local\Temp\ipykernel_14100\1617922371.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=payment_types.index, y=payment_types.values, palette="Set2")

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['payment_installments'], bins=20, kde=True, color="teal")
plt.xlabel("Number of Installments")
plt.ylabel("Frequency")
plt.title("Distribution of Payment Installments")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x=df['review_score'], palette="Spectral")
plt.xlabel("Review Score")
plt.ylabel("Number of Reviews")
plt.title("Distribution of Review Scores")
plt.show()
# Out:
# C:\Users\yassein ahmed\AppData\Local\Temp\ipykernel_14100\3776162366.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['review_score'], palette="Spectral")

# %%
df['review_length'] = df['review_comment_message'].astype(str).apply(len)

plt.figure(figsize=(10, 5))
sns.boxplot(x=df['review_score'], y=df['review_length'], palette="Blues")
plt.xlabel("Review Score")
plt.ylabel("Review Length (Characters)")
plt.title("Review Length vs Review Score")
plt.show()
# Out:
# C:\Users\yassein ahmed\AppData\Local\Temp\ipykernel_14100\362248692.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['review_score'], y=df['review_length'], palette="Blues")

# %%
low_rated_products = df[df['review_score'] < 3]
print(low_rated_products[['product_id', 'product_category_name', 'review_score']])
# Out:
#                               product_id   product_category_name  review_score
# 8       310ae3c140ff94b03219ad0adc3c778f            beleza_saude             1
# 17      4fa33915031a8cde03dd0d3e8fb27f01              perfumaria             1
# 31      28b4eced95a52d9c437a4caf9d311b95        moveis_decoracao             2
# 32      e95ee6822b66ac6058e2e4aff656071a           esporte_lazer             1
# 33      e95ee6822b66ac6058e2e4aff656071a           esporte_lazer             1
# ...                                  ...                     ...           ...
# 116549  550dc4417c636abc04c71404342de695  informatica_acessorios             2
# 116554  601a360bd2a916ecef0e88de72a6531a              cool_stuff             1
# 116555  681953ccd5c33207d75571a4bfbe127d            beleza_saude             2
# 116557  044f05bc9de36e8a693a83e4bc79dd0d               telefonia             2
# 116569  e7be84ea9462aac5e2b0b08eb35ba7f1   instrumentos_musicais             1
#
# ...

# %%
lowest_rated_products = df[df['review_score'] < 2]
print(lowest_rated_products[['product_id', 'product_category_name', 'review_score']])
# Out:
#                               product_id  product_category_name  review_score
# 8       310ae3c140ff94b03219ad0adc3c778f           beleza_saude             1
# 17      4fa33915031a8cde03dd0d3e8fb27f01             perfumaria             1
# 32      e95ee6822b66ac6058e2e4aff656071a          esporte_lazer             1
# 33      e95ee6822b66ac6058e2e4aff656071a          esporte_lazer             1
# 34      e95ee6822b66ac6058e2e4aff656071a          esporte_lazer             1
# ...                                  ...                    ...           ...
# 116533  547b95702aec86f05ac37e61d164891c     ferramentas_jardim             1
# 116536  3eef0cb94ba82de806bb30ab743c7655      moveis_escritorio             1
# 116541  801a695ff5c0c14970a71a4ceb70989e        casa_construcao             1
# 116554  601a360bd2a916ecef0e88de72a6531a             cool_stuff             1
# 116569  e7be84ea9462aac5e2b0b08eb35ba7f1  instrumentos_musicais             1
#
# [15110 rows x 3 columns]

# %%
lowest_rated_products = df[df['review_score'] < 2]

# Count occurrences of low-rated products by category
top_low_rated_categories = lowest_rated_products['product_category_name'].value_counts().nlargest(10)

# Plot the bar chart
plt.figure(figsize=(12, 5))
sns.barplot(x=top_low_rated_categories.index, y=top_low_rated_categories.values, palette="Reds")

# Formatting the chart
plt.xticks(rotation=90)
plt.xlabel("Product Category")
plt.ylabel("Number of Low Ratings")
plt.title("Top 10 Most Common Low-Rated Product Categories")
plt.show()
# Out:
# C:\Users\yassein ahmed\AppData\Local\Temp\ipykernel_14100\2260282325.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_low_rated_categories.index, y=top_low_rated_categories.values, palette="Reds")

# %%
df.isnull().sum()
# Out:
# order_id                              0
# order_item_id                         0
# product_id                            0
# seller_id                             0
# shipping_limit_date                   0
# price                                 0
# freight_value                         0
# payment_sequential                    0
# payment_type                          0
# payment_installments                  0
# payment_value                         0
# review_id                             0
# review_score                          0
# review_comment_title             102585
# review_comment_message            66703
# review_creation_date                  0
# review_answer_timestamp               0
# customer_id                           0
# order_status                          0
# order_purchase_timestamp              0
# order_approved_at                    14
# order_delivered_carrier_date       1213
# order_delivered_customer_date      2515
# ...

# %%
df = df.apply(lambda x: x.fillna(x.mean()), axis=0)

# %%
df.isnull().sum()
# Out:
# order_id                              0
# order_item_id                         0
# product_id                            0
# seller_id                             0
# shipping_limit_date                   0
# price                                 0
# freight_value                         0
# payment_sequential                    0
# payment_type                          0
# payment_installments                  0
# payment_value                         0
# review_id                             0
# review_score                          0
# review_comment_title             102585
# review_comment_message            66703
# review_creation_date                  0
# review_answer_timestamp               0
# customer_id                           0
# order_status                          0
# order_purchase_timestamp              0
# order_approved_at                    14
# order_delivered_carrier_date       1213
# order_delivered_customer_date      2515
# ...

# %%
# Assuming df is your DataFrame
for df['review_comment_title'] in df.columns:
    # Check if the column has any NaN values
    if df['review_comment_title'].isnull().sum() > 0:
        # Calculate the mean of the column (ignoring NaN values)
        mean_value = df['review_comment_title'].mean()
        # Replace NaN with the calculated mean
        df['review_comment_title'].fillna(mean_value, inplace=True)

# Check the result
print(df)
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 116576  fffc94f6ce00a00581880bf54a75a037              1
# 116577  fffcd46ef2263f404302a634eb57f7eb              1
# 116578  fffce4705a9662cd70adb13d4a31832d              1
# 116579  fffe18544ffabc95dfada21779c9644f              1
# 116580  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df.isnull().sum()
# Out:
# order_id                             0
# order_item_id                        0
# product_id                           0
# seller_id                            0
# shipping_limit_date                  0
# price                                0
# freight_value                        0
# payment_sequential                   0
# payment_type                         0
# payment_installments                 0
# payment_value                        0
# review_id                            0
# review_score                         0
# review_comment_title                 0
# review_comment_message           66703
# review_creation_date                 0
# review_answer_timestamp              0
# customer_id                          0
# order_status                         0
# order_purchase_timestamp             0
# order_approved_at                   14
# order_delivered_carrier_date      1213
# order_delivered_customer_date     2515
# order_estimated_delivery_date        0
# ...

# %%
for df['review_comment_message'] in df.columns:
    # Check if the column has any NaN values
    if df['review_comment_message'].isnull().sum() > 0:
        # Calculate the mean of the column (ignoring NaN values)
        mean_value = df['review_comment_message'].mean()
        # Replace NaN with the calculated mean
        df['review_comment_message'].fillna(mean_value, inplace=True)

# Check the result
print(df)
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 116576  fffc94f6ce00a00581880bf54a75a037              1
# 116577  fffcd46ef2263f404302a634eb57f7eb              1
# 116578  fffce4705a9662cd70adb13d4a31832d              1
# 116579  fffe18544ffabc95dfada21779c9644f              1
# 116580  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
for df['order_approved_at'] in df.columns:
    # Check if the column has any NaN values
    if df['order_approved_at'].isnull().sum() > 0:
        # Calculate the mean of the column (ignoring NaN values)
        mean_value = df['order_approved_at'].mean()
        # Replace NaN with the calculated mean
        df['order_approved_at'].fillna(mean_value, inplace=True)

# Check the result
print(df)
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 116576  fffc94f6ce00a00581880bf54a75a037              1
# 116577  fffcd46ef2263f404302a634eb57f7eb              1
# 116578  fffce4705a9662cd70adb13d4a31832d              1
# 116579  fffe18544ffabc95dfada21779c9644f              1
# 116580  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
for df['order_delivered_carrier_date'] in df.columns:
    # Check if the column has any NaN values
    if df['order_delivered_carrier_date'].isnull().sum() > 0:
        # Calculate the mean of the column (ignoring NaN values)
        mean_value = df['order_delivered_carrier_date'].mean()
        # Replace NaN with the calculated mean
        df['order_delivered_carrier_date'].fillna(mean_value, inplace=True)

# Check the result
print(df)
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 116576  fffc94f6ce00a00581880bf54a75a037              1
# 116577  fffcd46ef2263f404302a634eb57f7eb              1
# 116578  fffce4705a9662cd70adb13d4a31832d              1
# 116579  fffe18544ffabc95dfada21779c9644f              1
# 116580  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
for df['order_delivered_customer_date'] in df.columns:
    # Check if the column has any NaN values
    if df['order_delivered_customer_date'].isnull().sum() > 0:
        # Calculate the mean of the column (ignoring NaN values)
        mean_value = df['order_delivered_customer_date'].mean()
        # Replace NaN with the calculated mean
        df['order_delivered_customer_date'].fillna(mean_value, inplace=True)

# Check the result
print(df)
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 116576  fffc94f6ce00a00581880bf54a75a037              1
# 116577  fffcd46ef2263f404302a634eb57f7eb              1
# 116578  fffce4705a9662cd70adb13d4a31832d              1
# 116579  fffe18544ffabc95dfada21779c9644f              1
# 116580  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
for df['product_weight_g'] in df.columns:
    # Check if the column has any NaN values
    if df['product_weight_g'].isnull().sum() > 0:
        # Calculate the mean of the column (ignoring NaN values)
        mean_value = df['product_weight_g'].mean()
        # Replace NaN with the calculated mean
        df['product_weight_g'].fillna(mean_value, inplace=True)

# Check the result
print(df)
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 116576  fffc94f6ce00a00581880bf54a75a037              1
# 116577  fffcd46ef2263f404302a634eb57f7eb              1
# 116578  fffce4705a9662cd70adb13d4a31832d              1
# 116579  fffe18544ffabc95dfada21779c9644f              1
# 116580  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
for df['product_length_cm'] in df.columns:
    # Check if the column has any NaN values
    if df['product_length_cm'].isnull().sum() > 0:
        # Calculate the mean of the column (ignoring NaN values)
        mean_value = df['product_length_cm'].mean()
        # Replace NaN with the calculated mean
        df['product_length_cm'].fillna(mean_value, inplace=True)

# Check the result
print(df)
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 116576  fffc94f6ce00a00581880bf54a75a037              1
# 116577  fffcd46ef2263f404302a634eb57f7eb              1
# 116578  fffce4705a9662cd70adb13d4a31832d              1
# 116579  fffe18544ffabc95dfada21779c9644f              1
# 116580  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
for df['product_height_cm'] in df.columns:
    # Check if the column has any NaN values
    if df['product_height_cm'].isnull().sum() > 0:
        # Calculate the mean of the column (ignoring NaN values)
        mean_value = df['product_height_cm'].mean()
        # Replace NaN with the calculated mean
        df['product_height_cm'].fillna(mean_value, inplace=True)

# Check the result
print(df)
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 116576  fffc94f6ce00a00581880bf54a75a037              1
# 116577  fffcd46ef2263f404302a634eb57f7eb              1
# 116578  fffce4705a9662cd70adb13d4a31832d              1
# 116579  fffe18544ffabc95dfada21779c9644f              1
# 116580  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
for df['product_width_cm'] in df.columns:
    # Check if the column has any NaN values
    if df['product_width_cm'].isnull().sum() > 0:
        # Calculate the mean of the column (ignoring NaN values)
        mean_value = df['product_width_cm'].mean()
        # Replace NaN with the calculated mean
        df['product_width_cm'].fillna(mean_value, inplace=True)

# Check the result
print(df)
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 116576  fffc94f6ce00a00581880bf54a75a037              1
# 116577  fffcd46ef2263f404302a634eb57f7eb              1
# 116578  fffce4705a9662cd70adb13d4a31832d              1
# 116579  fffe18544ffabc95dfada21779c9644f              1
# 116580  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
for df['delivery_time'] in df.columns:
    # Check if the column has any NaN values
    if df['delivery_time'].isnull().sum() > 0:
        # Calculate the mean of the column (ignoring NaN values)
        mean_value = df['delivery_time'].mean()
        # Replace NaN with the calculated mean
        df['delivery_time'].fillna(mean_value, inplace=True)

# Check the result
print(df)
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 116576  fffc94f6ce00a00581880bf54a75a037              1
# 116577  fffcd46ef2263f404302a634eb57f7eb              1
# 116578  fffce4705a9662cd70adb13d4a31832d              1
# 116579  fffe18544ffabc95dfada21779c9644f              1
# 116580  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df.isnull().sum()
# Out:
# order_id                         0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# shipping_limit_date              0
# price                            0
# freight_value                    0
# payment_sequential               0
# payment_type                     0
# payment_installments             0
# payment_value                    0
# review_id                        0
# review_score                     0
# review_comment_title             0
# review_comment_message           0
# review_creation_date             0
# review_answer_timestamp          0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# customer_unique_id               0
# customer_zip_code_prefix         0
# customer_city                    0
# ...

# %%
for df['delivery_time'] in df.columns:
    # Check if the column has any NaN values
    if df['delivery_time'].isnull().sum() > 0:
        # Calculate the mean of the column (ignoring NaN values)
        mean_value = df['delivery_time'].mean()
        # Replace NaN with the calculated mean
        df['delivery_time'].fillna(mean_value, inplace=True)

# Check the result
print(df)
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 116576  fffc94f6ce00a00581880bf54a75a037              1
# 116577  fffcd46ef2263f404302a634eb57f7eb              1
# 116578  fffce4705a9662cd70adb13d4a31832d              1
# 116579  fffe18544ffabc95dfada21779c9644f              1
# 116580  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df.isnull().sum()
# Out:
# order_id                         0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# shipping_limit_date              0
# price                            0
# freight_value                    0
# payment_sequential               0
# payment_type                     0
# payment_installments             0
# payment_value                    0
# review_id                        0
# review_score                     0
# review_comment_title             0
# review_comment_message           0
# review_creation_date             0
# review_answer_timestamp          0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# customer_unique_id               0
# customer_zip_code_prefix         0
# customer_city                    0
# ...

# %%
sns.heatmap(df.isnull()) # for correlation
# Out:
# <Axes: >
